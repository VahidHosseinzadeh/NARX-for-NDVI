# %%
import ee
ee.Initialize()

# %%
from src.geometries import (
    id_to_ee, 
    all_pastures, 
    gdf_from_df, 
    id_to_ee_center_point 
    )

from src.data_sampling import (
    times_series_pixels_of_area, 
    get_df_point
    )
from src.data_preprocessing import (
    landsat, 
    pr_PRISM 
    )
from src.data_postprocessing import (
    time_stamp_adding, 
    merge_dfs,
    mean_over_region
    )
# Out:
# /Users/vahid/Desktop/NDVI Analysis/src/geometries.py:21: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   all_pastures['centers'] = all_pastures['geometry'].to_crs(epsg="4326").centroid

# %%
import pandas as pd
from src.geometries import id_to_ee_center_point
from src.geometries import all_pastures
SR_langum_center = id_to_ee_center_point(all_pastures,2)

from src.data_preprocessing import pr_PRISM
get_df_point(pr_PRISM,SR_langum_center,30,['tmean','tmax','tmin','ppt'])
# Out:
# 0            id  longitude   latitude           time  ...  Year Month Day  DOY
# 0      19810101 -96.995817  44.240366   347112000000  ...  1980    12  31  366
# 1      19810102 -96.995817  44.240366   347198400000  ...  1981     1   1    1
# 2      19810103 -96.995817  44.240366   347284800000  ...  1981     1   2    2
# 3      19810104 -96.995817  44.240366   347371200000  ...  1981     1   3    3
# 4      19810105 -96.995817  44.240366   347457600000  ...  1981     1   4    4
# ...         ...        ...        ...            ...  ...   ...   ...  ..  ...
# 15535  20230715 -96.995817  44.240366  1689336000000  ...  2023     7  14  195
# 15536  20230716 -96.995817  44.240366  1689422400000  ...  2023     7  15  196
# 15537  20230717 -96.995817  44.240366  1689508800000  ...  2023     7  16  197
# 15538  20230718 -96.995817  44.240366  1689595200000  ...  2023     7  17  198
# 15539  20230719 -96.995817  44.240366  1689681600000  ...  2023     7  18  199
#
# ...

# %%
from src.ndvi import ppt_temp_ndvi_pasture2

# %%
ppt_temp_ndvi_pasture2
# Out:
# 0            id  longitude   latitude           time      tmean       tmax  \
# 0      19810101 -96.995817  44.240366   347112000000     -1.088      2.786
# 1      19810102 -96.995817  44.240366   347198400000      -5.28      1.035
# 2      19810103 -96.995817  44.240366   347284800000    -10.078      2.153
# 3      19810104 -96.995817  44.240366   347371200000 -17.269001    -12.532
# 4      19810105 -96.995817  44.240366   347457600000 -10.875001     -6.448
# ...         ...        ...        ...            ...        ...        ...
# 15535  20230715 -96.995817  44.240366  1689336000000  21.465199  27.827099
# 15536  20230716 -96.995817  44.240366  1689422400000    18.3174  24.317699
# 15537  20230717 -96.995817  44.240366  1689508800000  16.132099    23.4783
# 15538  20230718 -96.995817  44.240366  1689595200000  16.972599  22.364199
# 15539  20230719 -96.995817  44.240366  1689681600000  20.289099    25.7759
#
# ...
