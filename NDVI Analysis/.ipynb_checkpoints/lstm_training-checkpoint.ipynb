# %%
import pandas as pd 
import altair as alt
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
# Out:
# 2023-09-18 09:48:10.737536: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
NDVI4 = pd.read_csv('./ndvi_ppt_tempt_pasture_ctwd4.csv')

# %%
df = NDVI4[['Timestamp','ppt','tmean','DOY','Month','GDD','NDVI']]

# %%
df
# Out:
#         Timestamp  ppt      tmean  DOY  Month          GDD      NDVI
# 0      1980-12-31  0.0   1.810000  366     12     0.000000       NaN
# 1      1981-01-01  0.0  -1.893000    1      1     0.000000       NaN
# 2      1981-01-02  0.0  -0.549000    2      1     0.000000       NaN
# 3      1981-01-03  0.0  -3.754000    3      1     0.000000       NaN
# 4      1981-01-04  0.0  -4.703000    4      1     0.000000       NaN
# ...           ...  ...        ...  ...    ...          ...       ...
# 15566  2023-08-14  0.0  18.735300  226      8  1667.664637  0.241827
# 15567  2023-08-15  0.0  24.603699  227      8  1687.268335       NaN
# 15568  2023-08-16  0.0  23.907598  228      8  1706.175934       NaN
# 15569  2023-08-17  0.0  21.076500  229      8  1722.252434       NaN
# 15570  2023-08-18  0.0  30.698000  230      8  1747.950434       NaN
#
# [15571 rows x 7 columns]

# %%
df.loc[:,'ppt'] = pd.to_numeric(df['ppt'])
df.loc[:,'tmean'] = pd.to_numeric(df['tmean'])
df.loc[:,'Timestamp'] = pd.to_datetime(df['Timestamp'])
# Out:
# /var/folders/sz/44hp86gj0lq16_fywprf9r580000gn/T/ipykernel_27327/2788524529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'ppt'] = pd.to_numeric(df['ppt'])
# /var/folders/sz/44hp86gj0lq16_fywprf9r580000gn/T/ipykernel_27327/2788524529.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'tmean'] = pd.to_numeric(df['tmean'])
# /var/folders/sz/44hp86gj0lq16_fywprf9r580000gn/T/ipykernel_27327/2788524529.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'Timestamp'] = pd.to_datetime(df['Timestamp'])
# /var/folders/sz/44hp86gj0lq16_fywprf9r580000gn/T/ipykernel_27327/2788524529.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:,'Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
number_of_features = 3

# %%
tf.keras.utils.timeseries_dataset_from_array()
# Out:
# <function keras.src.utils.timeseries_dataset.timeseries_dataset_from_array(data, targets, sequence_length, sequence_stride=1, sampling_rate=1, batch_size=128, shuffle=False, seed=None, start_index=None, end_index=None)>

# %%
for i in tf.data.Dataset.range(6).window(4,shift=1): 
    print(i)
# Out:
# <_VariantDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>
# <_VariantDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>
# <_VariantDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>
# <_VariantDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>
# <_VariantDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>
# <_VariantDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>

# %%
df_dropna = df.dropna()

# %%
df_dropna = df_dropna.set_index('Timestamp')

# %%
ndvi_train = df_dropna['NDVI']['1982-11-16':'2016-01-01']
ndvi_val = df_dropna['NDVI']['2016-01-01':'2017-01-01']
ndvi_test = df_dropna['NDVI']['2017-01-01':]

# %%
seq_length = 56
train_ds = tf.keras.utils.timeseries_dataset_from_array(
  ndvi_train.to_numpy(),
  targets=ndvi_train[seq_length:],
  sequence_length=seq_length,
  batch_size=32, 
  shuffle=True, 
  seed=42)

# %%
valid_ds = tf.keras.utils.timeseries_dataset_from_array(
      ndvi_val.to_numpy(),
      targets=ndvi_val[seq_length:],
      sequence_length=seq_length,
      batch_size=32
)

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1, input_shape=[seq_length])
])
early_stopping_cb = tf.keras.callbacks.EarlyStopping( monitor="val_mae", patience=50, restore_best_weights=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.02, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(), optimizer=opt,
metrics=["mae"])
history = model.fit(train_ds, validation_data=valid_ds,
epochs=500,
                  callbacks=[early_stopping_cb])
# Out:
# Epoch 1/500
#  1/19 [>.............................] - ETA: 6s - loss: 0.0063 - mae: 0.0859WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0068 - mae: 0.0944
# Epoch 2/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0076 - mae: 0.1034WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0058 - mae: 0.0875
# Epoch 3/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0049 - mae: 0.0818WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0050 - mae: 0.0812
# Epoch 4/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0042 - mae: 0.0710WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0045 - mae: 0.0765
# Epoch 5/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0039 - mae: 0.0665WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0041 - mae: 0.0725
# Epoch 6/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0034 - mae: 0.0665WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0036 - mae: 0.0686
# Epoch 7/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0038 - mae: 0.0709WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0034 - mae: 0.0655
# Epoch 8/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0040 - mae: 0.0726WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0031 - mae: 0.0626
# Epoch 9/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0021 - mae: 0.0552WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0028 - mae: 0.0601
# Epoch 10/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0019 - mae: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0027 - mae: 0.0577
# Epoch 11/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0026 - mae: 0.0577WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0025 - mae: 0.0562
# Epoch 12/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0027 - mae: 0.0590WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0024 - mae: 0.0545
# Epoch 13/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0023 - mae: 0.0466WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0023 - mae: 0.0526
# Epoch 14/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0018 - mae: 0.0511WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0021 - mae: 0.0511
# Epoch 15/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0027 - mae: 0.0560WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0021 - mae: 0.0499
# Epoch 16/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0012 - mae: 0.0427WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0020 - mae: 0.0490
# Epoch 17/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0022 - mae: 0.0534WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0019 - mae: 0.0479
# Epoch 18/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0028 - mae: 0.0550WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0018 - mae: 0.0470
# Epoch 19/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0017 - mae: 0.0459WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0018 - mae: 0.0465
# Epoch 20/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0025 - mae: 0.0581WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0017 - mae: 0.0455
# Epoch 21/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0017 - mae: 0.0470WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0017 - mae: 0.0449
# Epoch 22/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0014 - mae: 0.0426WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0443
# Epoch 23/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0016 - mae: 0.0439WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0436
# Epoch 24/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0012 - mae: 0.0386WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0435
# Epoch 25/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0019 - mae: 0.0509WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0016 - mae: 0.0426
# Epoch 26/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0015 - mae: 0.0430WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0015 - mae: 0.0423
# Epoch 27/500
#  1/19 [>.............................] - ETA: 1s - loss: 0.0013 - mae: 0.0442WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0418
# Epoch 28/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0024 - mae: 0.0515WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0414
# Epoch 29/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0014 - mae: 0.0456WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0015 - mae: 0.0412
# Epoch 30/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0026 - mae: 0.0536WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0408
# Epoch 31/500
#  1/19 [>.............................] - ETA: 0s - loss: 9.6105e-04 - mae: 0.0353WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0404
# Epoch 32/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0013 - mae: 0.0417WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0402
# Epoch 33/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0028 - mae: 0.0532WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0399
# Epoch 34/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0018 - mae: 0.0461WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0394
# Epoch 35/500
#  1/19 [>.............................] - ETA: 0s - loss: 8.9265e-04 - mae: 0.0337WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0393
# Epoch 36/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0012 - mae: 0.0390WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0389
# Epoch 37/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0011 - mae: 0.0377WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0388
# Epoch 38/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0012 - mae: 0.0415WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0385
# Epoch 39/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0013 - mae: 0.0406WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0383
# Epoch 40/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0019 - mae: 0.0393WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0381
# Epoch 41/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0012 - mae: 0.0371WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0013 - mae: 0.0379
# Epoch 42/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0014 - mae: 0.0411WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0013 - mae: 0.0377
# Epoch 43/500
#  1/19 [>.............................] - ETA: 0s - loss: 0.0019 - mae: 0.0397WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0012 - mae: 0.0377
# Epoch 44/500
#  1/19 [>.............................] - ETA: 0s - loss: 8
ARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 5.4144e-04 - mae: 0.0234
# Epoch 498/500
#  1/19 [>.............................] - ETA: 0s - loss: 8.5134e-04 - mae: 0.0279WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 4ms/step - loss: 5.3858e-04 - mae: 0.0234
# Epoch 499/500
#  1/19 [>.............................] - ETA: 0s - loss: 4.0718e-04 - mae: 0.0194WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 5.3853e-04 - mae: 0.0233
# Epoch 500/500
#  1/19 [>.............................] - ETA: 0s - loss: 2.7471e-04 - mae: 0.0182WARNING:tensorflow:Early stopping conditioned on metric `val_mae` which is not available. Available metrics are: loss,mae
# 19/19 [==============================] - 0s 5ms/step - loss: 5.3840e-04 - mae: 0.0234

# %%
model = tf.keras.Sequential([ tf.keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

# %%
deep_model = tf.keras.Sequential([ 
    tf.keras.layers.LSTM(32, return_sequences=True, input_shape=[None, 1]),
    
    # tf.keras.layers.LSTM(32, return_sequences=True), 
    tf.keras.layers.LSTM(32), 
    tf.keras.layers.Dense(1)
])

# %%
batch_size = 32
number_features = 4

# %%
(batch_size,time_window,number_features)
# Out:
# (32, 10, 5)

# %%
df
# Out:
#        Timestamp  ppt      tmean  DOY  Month          GDD      NDVI
# 0     1980-12-31  0.0   1.810000  366     12     0.000000       NaN
# 1     1981-01-01  0.0  -1.893000    1      1     0.000000       NaN
# 2     1981-01-02  0.0  -0.549000    2      1     0.000000       NaN
# 3     1981-01-03  0.0  -3.754000    3      1     0.000000       NaN
# 4     1981-01-04  0.0  -4.703000    4      1     0.000000       NaN
# ...          ...  ...        ...  ...    ...          ...       ...
# 15566 2023-08-14  0.0  18.735300  226      8  1667.664637  0.241827
# 15567 2023-08-15  0.0  24.603699  227      8  1687.268335       NaN
# 15568 2023-08-16  0.0  23.907598  228      8  1706.175934       NaN
# 15569 2023-08-17  0.0  21.076500  229      8  1722.252434       NaN
# 15570 2023-08-18  0.0  30.698000  230      8  1747.950434       NaN
#
# [15571 rows x 7 columns]

# %%
df = df.reset_index()

# %%
from sklearn.model_selection import train_test_split

# %%
def lstm_model(df, 
               time_window=5,
               feature_list = ['tmean','ppt','DOY','GDD'],  
               test_fraction = .1, 
               val_fraction = .7, 
               batch_size = 32,
               number_epochs = 1000): 
    number_of_sequences = len(df['NDVI'].dropna().index)
    data = [[df.iloc[index:index-time_window:-1] for index in df['NDVI'].dropna().index][i][feature_list].to_numpy() for i in range(number_of_sequences)]
    data = np.array(data)
    X = data
    y = df['NDVI'].dropna().to_numpy()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_fraction,shuffle=False)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = val_fraction, random_state=42)
    batch_size = 32
    number_features = len(feature_list)
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)
    
    deep_LSTM = tf.keras.Sequential([ 
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=[time_window, number_features]),
    
    tf.keras.layers.LSTM(32, return_sequences=True), 
    tf.keras.layers.LSTM(32), 
    tf.keras.layers.Dense(1)
    ])
    deep_LSTM.compile(loss = 'mean_squared_error', metrics=['mean_squared_error'],optimizer='adam')
    history=deep_LSTM.fit(X_train, y_train, epochs=number_epochs, validation_data=(X_val,y_val),batch_size=batch_size,verbose=0,callbacks=[early_stopping_cb])
    train_loss=history.history['loss']
    val_loss=history.history['val_loss']
    model_prediction = deep_LSTM.predict(X_test,verbose=0)
    model_prediction = model_prediction.reshape(len(model_prediction),)
    test_loss = mean_squared_error(y_test,model_prediction)
    r2 = r2_score(y_test,model_prediction)
    print(f"train loss : {train_loss[-1]:.{5}f}.")
    print(f"validation loss : {val_loss[-1]:.{5}f}.")
    print(f"test loss : {test_loss:.{5}f}.")
    print(f"r2 : {r2:.{5}f}.") 
    return train_loss, val_loss, model_prediction, y_test

# %%
train_loss, val_loss, model_prediction, y_test = lstm_model(df.reset_index(),time_window=30,feature_list=['tmean','ppt'])
# Out:
# train loss : 0.00075.
# validation loss : 0.00156.
# test loss : 0.00135.
# r2 : 0.65779.

# %%
train_loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(train_loss)+1)
plt.figure(figsize=(12,7))
plt.plot(epochs, train_loss,'b', label='Training loss')
plt.plot(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
time_window = 4
feature_list = ['tmean','ppt','DOY','GDD']
number_of_sequences = len(df['NDVI'].dropna().index)

data = [[df.iloc[index:index-time_window:-1] for index in df['NDVI'].dropna().index][i][feature_list].to_numpy() for i in range(number_of_sequences)]

# %%
data = np.array(data)

# %%
y = df['NDVI'].dropna().to_numpy()

# %%
X = data

# %%
X.shape
# Out:
# (958, 4, 4)

# %%
y.shape
# Out:
# (958,)

# %%
test_fraction = .1
val_fraction = .7

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_fraction,shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = val_fraction, random_state=42)

# %%
# number_of_train_val = int(len(data) - .1 * len(data))

# %%
# number_of_train = int(number_of_train_val - .1 * number_of_train_val)

# %%
# number_val = number_of_train_val - number_of_train

# %%
# assert number_of_train + number_val == number_of_train_val

# %%
# test_data = data[number_of_train_val:]
# train_data = data[:number_of_train]
# val_data = data[number_of_train:number_of_train+number_val]

# %%
# assert len(test_data) + len(train_data) +len(va_data) == len(data)

# %%
batch_size = 32
number_features = len(feature_list)

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)

# %%
deep_LSTM = tf.keras.Sequential([ 
    tf.keras.layers.LSTM(32, return_sequences=True, input_shape=[time_window, number_features]),
    
    # tf.keras.layers.LSTM(32, return_sequences=True), 
    tf.keras.layers.LSTM(32), 
    tf.keras.layers.Dense(1)
])

# %%
deep_LSTM.compile(loss = 'mean_squared_error', metrics=['mean_squared_error'],optimizer='adam')

# %%
number_epochs = 1000

# %%
history=deep_LSTM.fit(X_train, y_train, epochs=number_epochs, validation_data=(X_val,y_val),batch_size=batch_size,verbose=0,callbacks=[early_stopping_cb])

# %%
train_loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(train_loss)+1)
plt.figure(figsize=(12,7))
plt.plot(epochs, train_loss,'b', label='Training loss')
plt.plot(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
from sklearn.metrics import mean_squared_error, r2_score
model_prediction = deep_LSTM.predict(X_test,verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x14b202d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
model_prediction = model_prediction.reshape(len(model_prediction),)

# %%
test_loss = mean_squared_error(y_test,model_prediction)
r2 = r2_score(y_test,model_prediction)
print(f"train loss : {train_loss[-1]:.{5}f}.")
print(f"validation loss : {val_loss[-1]:.{5}f}.")
print(f"test loss : {test_loss:.{5}f}.")
print(f"r2 : {r2:.{5}f}.")
# Out:
# train loss : 0.00217.
# validation loss : 0.00193.
# test loss : 0.00106.
# r2 : 0.72995.

# %%
# df = df.set_index('Timestamp')

# %%
df_test = df[['NDVI']].reset_index().dropna().iloc[-len(y_test):]

# %%
timestamps_test = df_test.reset_index()['Timestamp']
time_start_test = timestamps_test.iloc[0]
df_test_with_all_values = df[time_start_test:]

# %%
y_test_df= pd.DataFrame(y_test,columns=['y_test'])
# long_term_preds_df = pd.DataFrame(long_term_forecast,columns=['preds_all_time'])
model_prediction_df = pd.DataFrame(model_prediction.reshape(len(model_prediction),1),columns=['preds'])

# %%
y_test_df['Timestamp'] = timestamps_test
model_prediction_df['Timestamp'] = timestamps_test

# %%
df_test_with_all_values = df_test_with_all_values.reset_index()

# %%
df_test_with_all_values.loc[:,'ppt_scaled'] = .008 * df_test_with_all_values['ppt'] 
df_test_with_all_values.loc[:,'tmean_scaled'] = .01 * df_test_with_all_values['tmean']

# %%
df_all_NDVI = alt.Chart(df_test_with_all_values.reset_index()).mark_point(color='black',opacity=1, size=5).encode(
    alt.X("Timestamp:T"), 
    alt.Y("NDVI:Q")
)


df_all_pastppt = alt.Chart(df_test_with_all_values.reset_index()).mark_line(color='blue',opacity=1, size=1).encode(
    alt.X("Timestamp:T"), 
    alt.Y("past_56_sum_ppt_scalded:Q")
)


df_all_ppt = alt.Chart(df_test_with_all_values.reset_index()).mark_bar(color='blue',opacity=1, size=1.5).encode(
    alt.X("Timestamp:T"), 
    alt.Y("ppt_scaled:Q")
)



df_all_tmean = alt.Chart(df_test_with_all_values.reset_index()).mark_bar(color='red',opacity=.5, size=1.5).encode(
    alt.X("Timestamp:T"), 
    alt.Y("tmean_scaled:Q")
)


#predictions 
y_test_df_plot = alt.Chart(y_test_df.reset_index()).mark_line(color='black',opacity=1, size=1,point={
      "filled": True,
      "fill": "black",
    "size" : 50,
    'opacity' : .5
    }).encode(
    alt.X("Timestamp:T"), 
    alt.Y("y_test:Q"),
    tooltip=[
        alt.Tooltip('y_test:O', title='NDVI')]
)
model_prediction_plot = alt.Chart(model_prediction_df.reset_index()).mark_line(color='blue',opacity=1,size=2,point={
      "filled": True,
      "fill": "lime",
    "size" : 50
    }).encode(
    alt.X("Timestamp:T"), 
    alt.Y("preds:Q"),
    tooltip=[
        alt.Tooltip('preds:O', title='NDVI_prediction')]
)



(df_all_NDVI+ df_all_ppt+ df_all_tmean + y_test_df_plot + model_prediction_plot).properties(width=1500, height=600)
# Out:
# alt.LayerChart(...)
